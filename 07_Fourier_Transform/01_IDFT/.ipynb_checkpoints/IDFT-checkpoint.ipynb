# %% [markdown]
# # Inverse Discrete Fourier Transform
#
# Any $N$ point signal, $x[i]$, can be created by adding $N/2 + 1$ cosine waves and $N/2 + 1$ sine waves. The amplitudes of the cosine and sine waves are held in the arrays $ImX[k]$ and $ReX[k]$, respectively. The synthesis equation multiplies these amplitudes by the basis functions to create a set of scaled sine and cosine waves. Adding the scaled sine and cosine waves produces the time domain signal, $x[i]$.

# %% [markdown]
# ## Synthesis Equation
# $x[i] = \displaystyle\sum_{k=0}^{N/2}{Re\bar{X}[k]\cos{(\frac{2\pi ki}{N}})} +
# \displaystyle\sum_{k=0}^{N/2}{Im\bar{X}[k]\sin{(\frac{2\pi ki}{N}})}$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Inverse Discrete Fourier Transform, IDFT
N = 32

Re_X = 32*np.ones(int(N/2) + 1)
mRe_X = Re_X/(N/2)
mRe_X[0] = Re_X[0]/N
mRe_X[int(N/2)] = Re_X[int(N/2)]/N


i = 0
k = 0
x = np.zeros(N)
for i in range(N):
    for k in range (int(N/2)+1):
        x[i] = x[i] + mRe_X[k]*np.cos(2*np.pi*k*i/N)

# %%
plt.rcParams["figure.figsize"] = (25,5)

plt.subplot(1, 2, 1)
plt.stem(mRe_X, use_line_collection=True)
plt.title('DFT Real Part')
plt.xlabel('sample')

plt.subplot(1, 2, 2)
plt.stem(x, use_line_collection=True)
plt.title('Signal')
plt.xlabel('sample')

plt.show()

# %%
class Fourier:
    def __init__(self, rex_signal, imx_signal):
            self.M = len(rex_signal)
            self.N = 2*(self.M - 1) 
            self.normRex = rex_signal/(self.N/2)
            #self.normRex[0] = self.normRex[0]/2
            #self.normRex[-1] = self.normRex[-1]/2
            self.normRex[0] = rex_signal[0]/self.N
            self.normRex[int(self.N/2)] = rex_signal[int(self.N/2)]/self.N

            self.normImx = -imx_signal/(self.N/2)
            
    
        
    def idft(self):       
        self.rex = np.zeros(self.N)
        self.imx = np.zeros(self.N)
        
        for i in range(self.N):
            for k in range (int(self.M)-1):
                self.rex[i] = self.rex[i] + self.normRex[k]*np.cos(2*np.pi*k*i/self.N)
                self.imx[i] = self.imx[i] + self.normImx[k]*np.sin(2*np.pi*k*i/self.N)
        self.idft_signal = self.rex + self.imx

# %%
rex = np.loadtxt(fname = "rex.dat").flatten()
imx = np.loadtxt(fname = "imx.dat").flatten()

# %%
idft = Fourier(rex, imx)
idft.idft()

# %%
x = np.loadtxt(fname = "signal.dat").flatten()
plt.rcParams["figure.figsize"] = (25,5)
plt.plot(idft.idft_signal, label='Synthetized Signal')
plt.plot(x, label='Original Signal')
plt.legend()

# %%
size = 100
error = np.zeros(size)
for k in range(size):
    if k==0:
        error[k] =  sum((x-idft.idft_signal)**2)/(len(x))
    else:
        error[k] =  sum((x[:-k]-idft.idft_signal[k:])**2)/(len(x)-k)
        
plt.bar(range(size), error);

# %%
x = np.loadtxt(fname = "signal.dat").flatten()
plt.rcParams["figure.figsize"] = (25,5)
plt.plot(idft.idft_signal, label='Synthetized Signal')
#plt.plot(x, label='Original Signal')
plt.legend()
plt.show()

# %%
# %matplotlib notebook
import matplotlib.animation as animation
from matplotlib.widgets import Slider

TWOPI = 2*np.pi

fig, ax = plt.subplots()

initial_amp = 1
s = idft.idft_signal
l, = plt.plot(s)

ax = plt.axis([0,len(idft.idft_signal),-3,3])

axamp = plt.axes([0.25, .03, 0.50, 0.02])
# Slider
samp = Slider(axamp, 'k', 0, 150, valinit=initial_amp, valstep=1)

def update(val):
    # amp is the current value of the slider
    amp = samp.val
    # update curve
    #print(idft.idft_signal[amp:])
    l.set_ydata(0.01*amp)
    # redraw canvas while idle
    fig.canvas.draw_idle()

# call update function on slider value change
samp.on_changed(update)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9833333333333">

# %%
idft.idft_signal[250:]
# Out:
# array([-9.59338927e-02,  1.92541263e-01,  9.98800453e-01,  4.18619260e-01,
#         3.52353843e-01,  1.25649265e+00,  8.64825857e-01,  4.63139314e-01,
#         1.31827967e+00,  1.18398612e+00,  4.98800453e-01,  1.18398612e+00,
#         1.31827967e+00,  4.63139314e-01,  8.64825857e-01,  1.25649265e+00,
#         3.52353843e-01,  4.18619260e-01,  9.98800453e-01,  1.92541263e-01,
#        -9.59338927e-02,  5.93665506e-01, -1.19954720e-03, -5.91266411e-01,
#         9.35347983e-02, -1.90142169e-01, -1.00119955e+00, -4.16220166e-01,
#        -3.54752938e-01, -1.25409356e+00, -8.67224951e-01, -4.60740219e-01,
#        -1.32067876e+00, -1.18158703e+00, -5.01199547e-01, -1.18158703e+00,
#        -1.32067876e+00, -4.60740219e-01, -8.67224951e-01, -1.25409356e+00,
#        -3.54752938e-01, -4.16220166e-01, -1.00119955e+00, -1.90142169e-01,
#         9.35347983e-02, -5.91266411e-01, -1.19954720e-03,  5.93665506e-01,
#        -9.59338927e-02,  1.92541263e-01,  9.98800453e-01,  4.18619260e-01,
#         3.52353843e-01,  1.25649265e+00,  8.64825857e-01,  4.63139314e-01,
#         1.31827967e+00,  1.18398612e+00,  4.98800453e-01,  1.18398612e+00,
#         1.31827967e+00,  4.63139314e-01,  8.64825857e-01,  1.25649265e+00,
#         3.52353843e-01,  4.18619260e-01,  9.98800453e-01,  1.92541263e-01,
#        -9.59338927e-02,  5.93665506e-01])
